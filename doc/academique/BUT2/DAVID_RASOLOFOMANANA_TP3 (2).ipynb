# %% [markdown]
# # TP 3 : Web-scraping avec Python #
# #### BUT 2 FA - VCOD ####
# Christella DAVID et
# Santatriniaina RASOLOFOMANANA

# %% [markdown]
# A partir du fichier StockEtablissement_utf8_1000__complété.csv sur les 1000 premiers établissements, dans lequel nous avons ajouté les coordonnées géographiques, vous devez chercher, pour chaque établissement, s’il existe un site web et récupérer l’adresse. Toutes les URL seront au final stockées dans une nouvelle variable, website, ajouté à toutes les autres informations.

# %%
import pandas

df = pandas.read_csv("C:/Users/ChristellaDAVID/Downloads/StockEtablissement_utf8_1000__complété.csv")
df
# Out:
#        siren  nic         siret statutDiffusionEtablissement  \
# 0     325175   16   32517500016                            O
# 1     325175   24   32517500024                            O
# 2     325175   32   32517500032                            O
# 3     325175   40   32517500040                            O
# 4     325175   57   32517500057                            O
# ..       ...  ...           ...                          ...
# 994  5742028   29  574202800029                            O
# 995  5742036   14  574203600014                            O
# 996  5742093   15  574209300015                            O
# 997  5742101   16  574210100016                            O
# 998  5742176   18  574217600018                            O
#
#     dateCreationEtablissement trancheEffectifsEtablissement  \
# 0                  2000-09-26                           NaN
# 1                  2008-05-20                           NaN
# 2                  2009-05-27                           NaN
# 3                  2011-10-21                           NaN
# 4                  2014-01-07                           NaN
# ..                        ...                           ...
# 994                2002-01-01                            NN
# 995                       NaN                           NaN
# 996                       NaN                           NaN
# 997                1900-01-01                            NN
# 998                       NaN                           NaN
#
#      anneeEffectifsEtablissement  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 994                          NaN
# 995                          NaN
# 996                          NaN
# 997                          NaN
# 998                          NaN
#
#     activitePrincipaleRegistreMetiersEtablissement  \
# 0                                           3212ZZ
# 1                                              NaN
# 2                                              NaN
# 3                                           3212ZZ
# 4                                              NaN
# ..                                             ...
# 994                                            NaN
# 995                                            NaN
# 996                                            NaN
# 997                                            NaN
# 998                                            NaN
#
#     dateDernierTraitementEtablissement  etablissementSiege  ...  \
# 0                  2015-03-18T00:58:59               False  ...
# 1                  2011-12-12T09:40:04               False  ...
# 2                  2014-07-08T00:10:21               False  ...
# 3                  2015-03-18T00:58:59               False  ...
# 4                  2018-07-10T14:17:15               False  ...
# ..                                 ...                 ...  ...
# 994                2013-12-11T08:50:11               False  ...
# 995                                NaN                True  ...
# 996                2019-08-25T12:02:35                True  ...
# 997                2019-11-14T14:00:14                True  ...
# 998                                NaN                True  ...
#
#      etatAdministratifEtablissement   enseigne1Etablissement  \
# 0                                 F                      NaN
# 1                                 F  TAHITI PERLES CREATIONS
# 2                                 F  TAHITI PERLES CREATIONS
# 3                                 F   TAHITI PERLES CREATION
# 4                                 F   TAHITI PERLES CREATION
# ..                              ...                      ...
# 994                               F                      NaN
# 995                               F                      NaN
# 996                               F                      NaN
# 997                               F                      NaN
# 998                               F                      NaN
#
#      enseigne2Etablissement enseigne3Etablissement  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
# ..                      ...                    ...
# 994                     NaN                    NaN
# 995                     NaN                    NaN
# 996                     NaN                    NaN
# 997                     NaN                    NaN
# 998                     NaN                    NaN
#
#     denominationUsuelleEtablissement activitePrincipaleEtablissement  \
# 0                                NaN                          32.12Z
# 1                                NaN                          47.89Z
# 2                                NaN                          32.12Z
# 3                                NaN                          32.12Z
# 4                                NaN                          32.12Z
# ..                               ...                             ...
# 994                              NaN                          01.11Z
# 995                              NaN                           69.22
# 996                              NaN                           62.43
# 997                              NaN                             NaN
# 998                              NaN                           00.97
#
#      nomenclatureActivitePrincipaleEtablissement  \
# 0                                        NAFRev2
# 1                                        NAFRev2
# 2                                        NAFRev2
# 3                                        NAFRev2
# 4                                        NAFRev2
# ..                                           ...
# 994                                      NAFRev2
# 995                                          NAP
# 996                                          NAP
# 997                                          NaN
# 998                                          NAP
#
#     caractereEmployeurEtablissement   latitude longitude
# 0                                 N  49.220518  6.015168
# 1                                 N  43.938190  4.882656
# 2                                 N  43.932374  4.844274
# 3                                 N  43.280158  5.623075
# 4                                 N  43.299866  5.397044
# ..                              ...        ...       ...
# 994                               N  44.115767  6.010904
# 995                               N  44.179140  5.947317
# 996                               N  44.197272  5.944793
# 997                               N  44.427401  6.435844
# 998                               N  44.197636  5.945917
#
# [999 rows x 50 columns]

# %% [markdown]
# ### Chargement des bibliothèques ###

# %%
import pandas
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ### Navigateur ###

# %%
driver = webdriver.Chrome()
base_url = "https://www.google.com/maps/search/"
place_info = "IUT+paris+rives+de+seine"
comp_url = "/@48.8489968,2.3125954,12z"
url = base_url + place_info + comp_url
driver.get(url)

# %% [markdown]
# ### Creation URL ###

# %%
def f(v, fin = False):
    r = ""
    if not(pandas.isna(v)):
        if isinstance(v, float):
            r += str(int(v))
        else:
            r += str(v)
        if not(fin):
            r += "+"
    return r

# %% [markdown]
# ### Recherche ###

# %%
site = []
for i in range(df.shape[0]):
    place_info = f(df["enseigne1Etablissement"][i]) + \
                 f(df["numeroVoieEtablissement"][i]) + f(df["indiceRepetitionEtablissement"][i]) + \
                 f(df["typeVoieEtablissement"][i]) + f(df["libelleVoieEtablissement"][i]) + \
                 f(df["codePostalEtablissement"][i]) + f(df["libelleCommuneEtablissement"][i], True)
    comp_url = "/@" +  str(df["latitude"][i]) + "," + str(df["longitude"][i]) + ",12z"
    url = base_url + place_info + comp_url
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html)
    results = soup.select("a[aria-label*='Site Web']")
    href = [None]
    if results != []:
        href += [results[0]["href"]]
    site += href
    time.sleep(1)

# %% [markdown]
# ### Resultat ###

# %%
site
df["site"] = site
df.to_csv("StockEtablissement_utf8_1000__avec_site.csv")
